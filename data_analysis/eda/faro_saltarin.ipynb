# %% [markdown]
# # Análisis exploratorio

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
from pathlib import Path
CSV = Path("../../data/by_game/faro_saltarin.csv")
df = pd.read_csv(CSV)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612 entries, 0 to 611
# Data columns (total 87 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   date                          612 non-null    object
#  1   9:00 ciclos                   612 non-null    int64
#  2   9:00 asistencia               612 non-null    int64
#  3   10:00 ciclos                  612 non-null    int64
#  4   10:00 asistencia              612 non-null    int64
#  5   11:00 ciclos                  612 non-null    int64
#  6   11:00 asistencia              612 non-null    int64
#  7   12:00 ciclos                  612 non-null    int64
#  8   12:00 asistencia              612 non-null    int64
#  9   13:00 ciclos                  612 non-null    int64
#  10  13:00 asistencia              612 non-null    int64
#  11  14:00 ciclos                  612 non-null    int64
#  12  14:00 asistencia              612 non-null    int64
#  13  15:00 ciclos                  612 non-null    float64
#  14  15:00 asistencia              612 non-null    float64
#  15  16:00 ciclos                  612 non-null    float64
#  16  16:00 asistencia              612 non-null    float64
#  17  17:00 ciclos                  612 non-null    float64
#  18  17:00 asistencia              612 non-null    float64
#  19  18:00 ciclos                  612 non-null    float64
#  20  18:00 asistencia              612 non-null    float64
#  21  ciclos total                  612 non-null    float64
#  22  asistencia total              612 non-null    float64
#  23  es_festivo                    612 non-null    bool
#  24  nombre_festivo                612 non-null    object
#  25  temperatura_max               612 non-null    float64
#  26  temperatura_min               612 non-null    float64
#  27  condiciones_cielo             612 non-null    object
#  28  prob_precipitacion            612 non-null    int64
#  29  promedio_asistencia_por_hora  612 non-null    float64
#  30  promedio_ciclos_por_hora      612 non-null    float64
#  31  source_file                   612 non-null    object
#  32  day                           612 non-null    int64
#  33  month                         612 non-null    int64
#  34  year                          612 non-null    int64
#  35  day_of_week                   612 non-null    object
#  36  temporada_alta                612 non-null    int64
#  37  lambda_9:00(/min)             612 non-null    float64
#  38  mu_9:00(/min)                 612 non-null    float64
#  39  rho_9:00                      612 non-null    float64
#  40  Wq_9:00(min)                  612 non-null    float64
#  41  state_9:00                    612 non-null    object
#  42  lambda_10:00(/min)            612 non-null    float64
#  43  mu_10:00(/min)                612 non-null    float64
#  44  rho_10:00                     612 non-null    float64
#  45  Wq_10:00(min)                 612 non-null    float64
#  46  state_10:00                   612 non-null    object
#  47  lambda_11:00(/min)            612 non-null    float64
#  48  mu_11:00(/min)                612 non-null    float64
#  49  rho_11:00                     612 non-null    float64
#  50  Wq_11:00(min)                 612 non-null    float64
#  51  state_11:00                   612 non-null    object
#  52  lambda_12:00(/min)            612 non-null    float64
#  53  mu_12:00(/min)                612 non-null    float64
#  54  rho_12:00                     612 non-null    float64
#  55  Wq_12:00(min)                 612 non-null    float64
#  56  state_12:00                   612 non-null    object
#  57  lambda_13:00(/min)            612 non-null    float64
#  58  mu_13:00(/min)                612 non-null    float64
#  59  rho_13:00                     612 non-null    float64
#  60  Wq_13:00(min)                 612 non-null    float64
#  61  state_13:00                   612 non-null    object
#  62  lambda_14:00(/min)            612 non-null    float64
#  63  mu_14:00(/min)                612 non-null    float64
#  64  rho_14:00                     612 non-null    float64
#  65  Wq_14:00(min)                 612 non-null    float64
#  66  state_14:00                   612 non-null    object
#  67  lambda_15:00(/min)            612 non-null    float64
#  68  mu_15:00(/min)                612 non-null    float64
#  69  rho_15:00                     612 non-null    float64
#  70  Wq_15:00(min)                 612 non-null    float64
#  71  state_15:00                   612 non-null    object
#  72  lambda_16:00(/min)            612 non-null    float64
#  73  mu_16:00(/min)                612 non-null    float64
#  74  rho_16:00                     612 non-null    float64
#  75  Wq_16:00(min)                 612 non-null    float64
#  76  state_16:00                   612 non-null    object
#  77  lambda_17:00(/min)            612 non-null    float64
#  78  mu_17:00(/min)                612 non-null    float64
#  79  rho_17:00                     612 non-null    float64
#  80  Wq_17:00(min)                 612 non-null    float64
#  81  state_17:00                   612 non-null    object
#  82  lambda_18:00(/min)            612 non-null    float64
#  83  mu_18:00(/min)                612 non-null    float64
#  84  rho_18:00                     612 non-null    float64
#  85  Wq_18:00(min)                 612 non-null    float64
#  86  state_18:00                   612 non-null    object
# dtypes: bool(1), float64(54), int64(17), object(15)
# memory usage: 411.9+ KB

# %% [markdown]
# ### Datos faltantes

# %%
na = df.isna().mean().sort_values(ascending=False)
display(na.head(20))
# Out:
# date                  0.0
# Wq_12:00(min)         0.0
# mu_14:00(/min)        0.0
# lambda_14:00(/min)    0.0
# state_13:00           0.0
# Wq_13:00(min)         0.0
# rho_13:00             0.0
# mu_13:00(/min)        0.0
# lambda_13:00(/min)    0.0
# state_12:00           0.0
# rho_12:00             0.0
# Wq_14:00(min)         0.0
# mu_12:00(/min)        0.0
# lambda_12:00(/min)    0.0
# state_11:00           0.0
# Wq_11:00(min)         0.0
# rho_11:00             0.0
# mu_11:00(/min)        0.0
# lambda_11:00(/min)    0.0
# state_10:00           0.0
# dtype: float64

# %% [markdown]
# ## EDA visual

# %% [markdown]
# ### Asistencia total por año

# %%
plt.figure(figsize=(8,4))
plt.bar(df["year"].astype(str), df["asistencia total"])
plt.title("Yearly Attendance")
plt.xlabel("Year")
plt.ylabel("Total Attendance")
plt.show()

# %% [markdown]
# ### Asistencia por día de la semana

# %%
if {"day_of_week","asistencia total"}.issubset(df.columns):
    plt.figure(figsize=(10,5))
    sns.boxplot(data=df, x="day_of_week", y="asistencia total")
    plt.xlabel("Day of Week")
    plt.ylabel("Total Attendance")
    plt.title("Day of Week vs Total Attendance")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### Matriz de correlación

# %%
num = df.select_dtypes(include=[np.number])
plt.figure(figsize=(12,9))
sns.heatmap(num.corr(), cmap="coolwarm", center=0)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ### Limpieza de datos

# %%
# Columnas a mantener
horas = [f"{h}:00" for h in range(9, 19)]

base_keep = [c for c in [
    "date", "day_of_week", "es_festivo", "nombre_festivo",
    "temperatura_max", "condiciones_cielo", "temporada_alta",
] if c in df.columns]

wq_cols     = [c for c in df.columns if c.startswith("Wq_") and "(min)" in c]
state_cols  = [c for c in df.columns if c.startswith("state_")]
asis_h_cols = [f"{h} asistencia" for h in horas if f"{h} asistencia" in df.columns]
cic_h_cols  = [f"{h} ciclos"     for h in horas if f"{h} ciclos"     in df.columns]
hourly_keep = [c for c in df.columns if c.endswith("asistencia") or c.endswith("ciclos")]

# Columnas finales a mantener (sin duplicados)
keep_cols = list(dict.fromkeys(base_keep + wq_cols + state_cols + hourly_keep))

# %%
# Columnas a eliminar
drop_patterns = ("lambda_", "mu_", "rho_", "promedio_")

drop_by_pattern = [c for c in df.columns if c.startswith(drop_patterns)]
drop_the_rest = [c for c in df.columns if c not in keep_cols and c not in drop_by_pattern]

cols_to_drop = drop_by_pattern + drop_the_rest

# Eliminar columnas
df_final = df.drop(columns=cols_to_drop)

# %%
print(f"Originales: {len(df.columns)}")
print(f"Mantener: {len(df_final.columns)} -> {sorted(df_final.columns)[:29]} ...")
print(f"Eliminar:  {len(cols_to_drop)}")
# Out:
# Originales: 87
# Mantener: 47 -> ['10:00 asistencia', '10:00 ciclos', '11:00 asistencia', '11:00 ciclos', '12:00 asistencia', '12:00 ciclos', '13:00 asistencia', '13:00 ciclos', '14:00 asistencia', '14:00 ciclos', '15:00 asistencia', '15:00 ciclos', '16:00 asistencia', '16:00 ciclos', '17:00 asistencia', '17:00 ciclos', '18:00 asistencia', '18:00 ciclos', '9:00 asistencia', '9:00 ciclos', 'Wq_10:00(min)', 'Wq_11:00(min)', 'Wq_12:00(min)', 'Wq_13:00(min)', 'Wq_14:00(min)', 'Wq_15:00(min)', 'Wq_16:00(min)', 'Wq_17:00(min)', 'Wq_18:00(min)'] ...
# Eliminar:  40

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612 entries, 0 to 611
# Data columns (total 47 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               612 non-null    object
#  1   9:00 ciclos        612 non-null    int64
#  2   9:00 asistencia    612 non-null    int64
#  3   10:00 ciclos       612 non-null    int64
#  4   10:00 asistencia   612 non-null    int64
#  5   11:00 ciclos       612 non-null    int64
#  6   11:00 asistencia   612 non-null    int64
#  7   12:00 ciclos       612 non-null    int64
#  8   12:00 asistencia   612 non-null    int64
#  9   13:00 ciclos       612 non-null    int64
#  10  13:00 asistencia   612 non-null    int64
#  11  14:00 ciclos       612 non-null    int64
#  12  14:00 asistencia   612 non-null    int64
#  13  15:00 ciclos       612 non-null    float64
#  14  15:00 asistencia   612 non-null    float64
#  15  16:00 ciclos       612 non-null    float64
#  16  16:00 asistencia   612 non-null    float64
#  17  17:00 ciclos       612 non-null    float64
#  18  17:00 asistencia   612 non-null    float64
#  19  18:00 ciclos       612 non-null    float64
#  20  18:00 asistencia   612 non-null    float64
#  21  es_festivo         612 non-null    bool
#  22  nombre_festivo     612 non-null    object
#  23  temperatura_max    612 non-null    float64
#  24  condiciones_cielo  612 non-null    object
#  25  day_of_week        612 non-null    object
#  26  temporada_alta     612 non-null    int64
#  27  Wq_9:00(min)       612 non-null    float64
#  28  state_9:00         612 non-null    object
#  29  Wq_10:00(min)      612 non-null    float64
#  30  state_10:00        612 non-null    object
#  31  Wq_11:00(min)      612 non-null    float64
#  32  state_11:00        612 non-null    object
#  33  Wq_12:00(min)      612 non-null    float64
#  34  state_12:00        612 non-null    object
#  35  Wq_13:00(min)      612 non-null    float64
#  36  state_13:00        612 non-null    object
#  37  Wq_14:00(min)      612 non-null    float64
#  38  state_14:00        612 non-null    object
#  39  Wq_15:00(min)      612 non-null    float64
#  40  state_15:00        612 non-null    object
#  41  Wq_16:00(min)      612 non-null    float64
#  42  state_16:00        612 non-null    object
#  43  Wq_17:00(min)      612 non-null    float64
#  44  state_17:00        612 non-null    object
#  45  Wq_18:00(min)      612 non-null    float64
#  46  state_18:00        612 non-null    object
# dtypes: bool(1), float64(19), int64(13), object(14)
# memory usage: 220.7+ KB

# %%
# ============================================
# Reformateo a formato largo 
# ============================================

# --- Configuración ---
USAR_ASISTENCIA_POR_HORA = True   
HORAS = [f"{h}:00" for h in range(9, 19)]  # 9:00..18:00

# Poner fecha en formato datetime y extraer año/mes/día
df_final = df_final.copy()
df_final["date"] = pd.to_datetime(df_final["date"], errors="coerce")
df_final["year"]  = df_final["date"].dt.year
df_final["month"] = df_final["date"].dt.month
df_final["day"]   = df_final["date"].dt.day

base_cols = [c for c in [
     "date", "day_of_week", "es_festivo", "nombre_festivo",
    "temperatura_max", "condiciones_cielo", "temporada_alta",
    "year","month","day"
] if c in df_final.columns]

# --- Construcción del DF largo ---
registros = []

def col_exists(df, col): 
    return col in df.columns

def col_h(df, h, sufijo): 
    cand = f"{h} {sufijo}"
    return cand if col_exists(df, cand) else None

for h in HORAS:
    wq_col = f"Wq_{h}(min)"
    if not col_exists(df_final, wq_col):
        continue  # si no existe Wq de esta hora, se salta

    # Subset con columnas base
    sub = df_final[base_cols].copy()
    sub["hora"] = h

    # Variables por hora (opcional)
    if USAR_ASISTENCIA_POR_HORA:
        asis_h = col_h(df_final, h, "asistencia")
        cic_h  = col_h(df_final, h, "ciclos")
        if asis_h: sub["asistencia_h"] = df_final[asis_h]
        if cic_h:  sub["ciclos_h"]     = df_final[cic_h]

    # Estado por hora (para filtrar cierres luego)
    state_h = f"state_{h}"
    sub["state"] = df_final[state_h] if col_exists(df_final, state_h) else np.nan

    # Objetivo
    sub["Wq"] = df_final[wq_col]

    registros.append(sub)

# Concatenar todo
df_final = pd.concat(registros, ignore_index=True)

# Tipos/categóricas útiles
for c in ["day_of_week","condiciones_cielo","nombre_festivo","hora","state"]:
    if c in df_final.columns:
        df_final[c] = df_final[c].astype("category")

print("Shape df_final:", df_final.shape)
print("Columnas:", list(df_final.columns))
df_final.head()
# Out:
# Shape df_final: (6120, 15)
# Columnas: ['date', 'day_of_week', 'es_festivo', 'nombre_festivo', 'temperatura_max', 'condiciones_cielo', 'temporada_alta', 'year', 'month', 'day', 'hora', 'asistencia_h', 'ciclos_h', 'state', 'Wq']
#         date day_of_week  es_festivo   nombre_festivo  temperatura_max  \
# 0 2022-01-01    Saturday        True        Año Nuevo             26.0
# 1 2022-04-01      Friday       False          Ninguno             28.0
# 2 2022-05-01      Sunday        True  Día del Trabajo             28.0
# 3 2022-07-01      Friday       False          Ninguno             25.0
# 4 2022-09-01    Thursday       False          Ninguno             22.0
#
#                condiciones_cielo  temporada_alta  year  month  day  hora  \
# 0           Patchy rain possible               0  2022      1    1  9:00
# 1                       Overcast               1  2022      4    1  9:00
# 2           Patchy rain possible               0  2022      5    1  9:00
# 3           Patchy rain possible               0  2022      7    1  9:00
# 4  Moderate or heavy rain shower               0  2022      9    1  9:00
#
#    asistencia_h  ciclos_h   state        Wq
# 0           0.0       0.0  Closed  0.000000
# 1           0.0       0.0  Closed  0.000000
# 2           0.0       0.0  Closed  0.000000
# 3          47.0       6.0  stable  1.199809
# 4           6.0       2.0  stable  0.705225

# %%
FILTRAR_CERRADOS = True   
ELIMINAR_WQ_CERO = True

# Filtrar horas cerradas (state = Closed)
if FILTRAR_CERRADOS and "state" in df_final.columns:
    mask_closed = df_final["state"].astype(str).str.lower().str.contains("closed", na=False)
    print("Filas con estado cerrado:", int(mask_closed.sum()))
    df_final = df_final[~mask_closed].copy()

# Eliminar Wq <= 0 
if ELIMINAR_WQ_CERO:
    zeros = int((df_final["Wq"] <= 0).sum())
    print("Filas con Wq <= 0:", zeros)
    df_final = df_final[df_final["Wq"] > 0].copy()

if "state" in df_final.columns:
    df_final = df_final.drop(columns=["state"])

print("Shape después de limpieza:", df_final.shape)
df_final = df_final.sort_values(["date", "hora"])
df_final.head(40)
# Out:
# Filas con estado cerrado: 1491
# Filas con Wq <= 0: 1
# Shape después de limpieza: (4628, 14)
#            date day_of_week  es_festivo nombre_festivo  temperatura_max  \
# 612  2022-01-01    Saturday        True      Año Nuevo             26.0
# 1224 2022-01-01    Saturday        True      Año Nuevo             26.0
# 1836 2022-01-01    Saturday        True      Año Nuevo             26.0
# 2448 2022-01-01    Saturday        True      Año Nuevo             26.0
# 3060 2022-01-01    Saturday        True      Año Nuevo             26.0
# 3672 2022-01-01    Saturday        True      Año Nuevo             26.0
# 4284 2022-01-01    Saturday        True      Año Nuevo             26.0
# 4896 2022-01-01    Saturday        True      Año Nuevo             26.0
# 619  2022-01-02      Sunday       False        Ninguno             27.0
# 1231 2022-01-02      Sunday       False        Ninguno             27.0
# 1843 2022-01-02      Sunday       False        Ninguno             27.0
# 2455 2022-01-02      Sunday       False        Ninguno             27.0
# 3067 2022-01-02      Sunday       False        Ninguno             27.0
# 3679 2022-01-02      Sunday       False        Ninguno             27.0
# 4291 2022-01-02      Sunday       False        Ninguno             27.0
# 4903 2022-01-02      Sunday       False        Ninguno             27.0
# 7    2022-01-02      Sunday       False        Ninguno             27.0
# 649  2022-01-06    Thursday       False        Ninguno             26.0
# 1261 2022-01-06    Thursday       False        Ninguno             26.0
# 1873 2022-01-06    Thursday       False        Ninguno             26.0
# 2485 2022-01-06    Thursday       False        Ninguno             26.0
# 3097 2022-01-06    Thursday       False        Ninguno             26.0
# 3709 2022-01-06    Thursday       False        Ninguno             26.0
# 4321 2022-01-06    Thursday       False        Ninguno             26.0
# 37   2022-01-06    Thursday       False        Ninguno             26.0
# 657  2022-01-07      Friday       False        Ninguno             24.0
# 1269 2022-01-07      Friday       False        Ninguno             24.0
# 1881 2022-01-07      Friday       False        Ninguno             24.0
# 2493 2022-01-07      Friday       False        Ninguno             24.0
# 3105 2022-01-07      Friday       False        Ninguno             24.0
# 3717 2022-01-07      Friday       False        Ninguno             24.0
# 4329 2022-01-07      Friday       False        Ninguno             24.0
# 45   2022-01-07      Friday       False        Ninguno             24.0
# 665  2022-01-08    Saturday       False        Ninguno             25.0
# 1277 2022-01-08    Saturday       False        Ninguno             25.0
# 1889 2022-01-08    Saturday       False        Ninguno             25.0
# 2501 2022-01-08    Saturday       False        Ninguno             25.0
# 3113 2022-01-08    Saturday       False        Ninguno             25.0
# 3725 2022-01-08    Saturday       False        Ninguno             25.0
# 4337 2022-01-08    Saturday       False        Ninguno             25.0
#
#                   condiciones_cielo  temporada_alta  year  month  day   hora  \
# 612            Patchy rain possible               0  2022      1    1  10:00
# 1224           Patchy rain possible               0  2022      1    1  11:00
# 1836           Patchy rain possible               0  2022      1    1  12:00
# 2448           Patchy rain possible               0  2022      1    1  13:00
# 3060           Patchy rain possible               0  2022      1    1  14:00
# 3672           Patchy rain possible               0  2022      1    1  15:00
# 4284           Patchy rain possible               0  2022      1    1  16:00
# 4896           Patchy rain possible               0  2022      1    1  17:00
# 619            Patchy rain possible               0  2022      1    2  10:00
# 1231           Patchy rain possible               0  2022      1    2  11:00
# 1843           Patchy rain possible               0  2022      1    2  12:00
# 2455           Patchy rain possible               0  2022      1    2  13:00
# 3067           Patchy rain possible               0  2022      1    2  14:00
# 3679           Patchy rain possible               0  2022      1    2  15:00
# 4291           Patchy rain possible               0  2022      1    2  16:00
# 4903           Patchy rain possible               0  2022      1    2  17:00
# 7              Patchy rain possible               0  2022      1    2   9:00
# 649            Patchy rain possible               0  2022      1    6  10:00
# 1261           Patchy rain possible               0  2022      1    6  11:00
# 1873           Patchy rain possible               0  2022      1    6  12:00
# 2485           Patchy rain possible               0  2022      1    6  13:00
# 3097           Patchy rain possible               0  2022      1    6  14:00
# 3709           Patchy rain possible               0  2022      1    6  15:00
# 4321           Patchy rain possible               0  2022      1    6  16:00
# 37             Patchy rain possible               0  2022      1    6   9:00
# 657   Moderate or heavy rain shower               0  2022      1    7  10:00
# 1269  Moderate or heavy rain shower               0  2022      1    7  11:00
# 1881  Moderate or heavy rain shower               0  2022      1    7  12:00
# 2493  Moderate or heavy rain shower               0  2022      1    7  13:00
# 3105  Moderate or heavy rain shower               0  2022      1    7  14:00
# 3717  Moderate or heavy rain shower               0  2022      1    7  15:00
# 4329  Moderate or heavy rain shower               0  2022      1    7  16:00
# 45    Moderate or heavy rain shower               0  2022      1    7   9:00
# 665            Patchy rain possible               0  2022      1    8  10:00
# 1277           Patchy rain possible               0  2022      1    8  11:00
# 1889           Patchy rain possible               0  2022      1    8  12:00
# 2501           Patchy rain possible               0  2022      1    8  13:00
# 3113           Patchy rain possible               0  2022      1    8  14:00
# 3725           Patchy rain possible               0  2022      1    8  15:00
# 4337           Patchy rain possible               0  2022      1    8  16:00
#
#       asistencia_h  ciclos_h         Wq
# 612           91.0       9.0   1.876916
# 1224         129.0      11.0   4.244117
# 1836         127.0      11.0   3.615808
# 2448         130.0      11.0   4.637765
# 3060         118.0      11.0   2.092126
# 3672         123.0      11.0   2.759047
# 4284         118.0      11.0   2.092126
# 4896         118.0      11.0   2.092126
# 619          128.0      10.0  60.000000
# 1231         127.0      11.0   3.615808
# 1843         129.0      11.0   4.244117
# 2455         133.0      11.0   6.352104
# 3067         130.0      11.0   4.637765
# 3679         127.0      11.0   3.615808
# 4291         126.0      11.0   3.361092
# 4903         133.0      11.0   6.352104
# 7            110.0      10.0   2.699296
# 649          120.0      10.0   6.231168
# 1261         129.0      11.0   4.244117
# 1873         119.0      11.0   2.202167
# 2485         117.0      11.0   1.990940
# 3097         115.0      11.0   1.811173
# 3709         121.0      11.0   2.453906
# 4321         120.0      11.0   2.322277
# 37            41.0       6.0   0.874005
# 657          108.0      11.0   1.349248
# 1269         101.0      11.0   1.045608
# 1881         101.0      10.0   1.680662
# 2493         100.0      10.0   1.606563
# 3105         105.0      11.0   1.204993
# 3717         121.0      11.0   2.453906
# 4329          82.0       9.0   1.244434
# 45            33.0       4.0   2.065432
# 665          112.0      10.0   3.072475
# 1277         119.0      10.0   5.558836
# 1889         115.0      10.0   3.832734
# 2501         125.0      11.0   3.136599
# 3113         124.0      11.0   2.937251
# 3725         113.0      11.0   1.656326
# 4337         126.0      10.0  19.805010

# %%
cat_cols = [c for c in ["day_of_week","hora","es_festivo", "condiciones_cielo", "nombre_festivo"]
            if c in df_final.columns]

num_cols = [c for c in ["month","day","temperatura_max", "temporada_alta", "asistencia_h", "ciclos_h"]
            if c in df_final.columns]

features = cat_cols + num_cols
X_all = df_final[features].copy()
y_all = df_final["Wq"].astype(float)


print("Features categóricas:", cat_cols)
print("Features numéricas:", num_cols)
print("X shape:", X_all.shape, "| y shape:", y_all.shape)
# Out:
# Features categóricas: ['day_of_week', 'hora', 'es_festivo', 'condiciones_cielo', 'nombre_festivo']
# Features numéricas: ['month', 'day', 'temperatura_max', 'temporada_alta', 'asistencia_h', 'ciclos_h']
# X shape: (4628, 11) | y shape: (4628,)

# %%
X_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4628 entries, 612 to 607
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   day_of_week        4628 non-null   category
#  1   hora               4628 non-null   category
#  2   es_festivo         4628 non-null   bool
#  3   condiciones_cielo  4628 non-null   category
#  4   nombre_festivo     4628 non-null   category
#  5   month              4628 non-null   int32
#  6   day                4628 non-null   int32
#  7   temperatura_max    4628 non-null   float64
#  8   temporada_alta     4628 non-null   int64
#  9   asistencia_h       4628 non-null   float64
#  10  ciclos_h           4628 non-null   float64
# dtypes: bool(1), category(4), float64(3), int32(2), int64(1)
# memory usage: 241.0 KB

# %%
X_all.head(10)
# Out:
#      day_of_week   hora  es_festivo     condiciones_cielo nombre_festivo  \
# 612     Saturday  10:00        True  Patchy rain possible      Año Nuevo
# 1224    Saturday  11:00        True  Patchy rain possible      Año Nuevo
# 1836    Saturday  12:00        True  Patchy rain possible      Año Nuevo
# 2448    Saturday  13:00        True  Patchy rain possible      Año Nuevo
# 3060    Saturday  14:00        True  Patchy rain possible      Año Nuevo
# 3672    Saturday  15:00        True  Patchy rain possible      Año Nuevo
# 4284    Saturday  16:00        True  Patchy rain possible      Año Nuevo
# 4896    Saturday  17:00        True  Patchy rain possible      Año Nuevo
# 619       Sunday  10:00       False  Patchy rain possible        Ninguno
# 1231      Sunday  11:00       False  Patchy rain possible        Ninguno
#
#       month  day  temperatura_max  temporada_alta  asistencia_h  ciclos_h
# 612       1    1             26.0               0          91.0       9.0
# 1224      1    1             26.0               0         129.0      11.0
# 1836      1    1             26.0               0         127.0      11.0
# 2448      1    1             26.0               0         130.0      11.0
# 3060      1    1             26.0               0         118.0      11.0
# 3672      1    1             26.0               0         123.0      11.0
# 4284      1    1             26.0               0         118.0      11.0
# 4896      1    1             26.0               0         118.0      11.0
# 619       1    2             27.0               0         128.0      10.0
# 1231      1    2             27.0               0         127.0      11.0

# %%
# Ver porcentaje de outliers usando método IQR
Q1 = y_all.quantile(0.25)
Q3 = y_all.quantile(0.75)
IQR = Q3 - Q1
umbral_inferior = Q1 - 1.5 * IQR
umbral_superior = Q3 + 1.5 * IQR

# Identificar outliers
outliers_mask = (y_all < umbral_inferior) | (y_all > umbral_superior)
num_outliers = outliers_mask.sum()
porcentaje_outliers = (num_outliers / len(y_all)) * 100

print(f"Total de datos: {len(y_all)}")
print(f"Q1: {Q1:.4f}, Q3: {Q3:.4f}, IQR: {IQR:.4f}")
print(f"Rango normal: [{umbral_inferior:.4f}, {umbral_superior:.4f}]")
print(f"Outliers encontrados: {num_outliers} ({porcentaje_outliers:.2f}%)")

print("Valores atípicos en y_all:")
print(y_all[outliers_mask])

# Eliminar outliers
if porcentaje_outliers < 5:  # Solo eliminar si es menos del 5%
    X_clean = X_all[~outliers_mask]
    y_clean = y_all[~outliers_mask]
else:
    X_clean = X_all.copy()
    y_clean = y_all.copy()
    print("No se eliminaron outliers debido a su alto porcentaje.")
# Out:
# Total de datos: 4628
# Q1: 1.7095, Q3: 21.4146, IQR: 19.7051
# Rango normal: [-27.8481, 50.9723]
# Outliers encontrados: 1025 (22.15%)
# Valores atípicos en y_all:
# 619     60.0
# 4956    60.0
# 2563    60.0
# 3175    60.0
# 3787    60.0
#         ...
# 2421    60.0
# 3645    60.0
# 4257    60.0
# 1825    60.0
# 4885    60.0
# Name: Wq, Length: 1025, dtype: float64
# No se eliminaron outliers debido a su alto porcentaje.

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline as SkPipeline

RANDOM_STATE = 42
X_train, X_test, y_train, y_test = train_test_split(X_clean, y_clean, test_size=0.2, random_state=RANDOM_STATE)

# %%
from sklearn.impute import SimpleImputer

pre = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False, drop=None), cat_cols),
        ("num", SkPipeline(steps=[
            ("imputer", SimpleImputer(strategy="median")),
            # no scaler, RF no lo necesita
        ]), num_cols),
    ],
    remainder="drop"
)

rf = RandomForestRegressor(
    n_estimators=600, max_depth=None, min_samples_leaf=2, min_samples_split=4,
    max_features="sqrt", n_jobs=-1, random_state=RANDOM_STATE, bootstrap=True
)

pipe = Pipeline(steps=[("pre", pre), ("model", rf)])

# %%
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

def report(y_true, y_pred, name="modelo"):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred, squared=False)
    r2 = r2_score(y_true, y_pred)
    print(f"[{name}] MAE={mae:,.2f} | RMSE={rmse:,.2f} | R²={r2:,.3f}")

report(y_test, y_pred, "RF Pipeline (clean + imputer)")
# Out:
# [RF Pipeline (clean + imputer)] MAE=7.15 | RMSE=10.38 | R²=0.804
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import sklearn 
bundle = {
    "pipeline": pipe,
    "cat_cols": cat_cols,
    "num_cols": num_cols,
    "version": sklearn.__version__,
    "notes": "OneHot + SimpleImputer; sin passthrough"
}

# %%
import os, joblib
os.makedirs("../models", exist_ok=True)
joblib.dump(bundle, "../models/faro_saltarin.joblib")
print("✅ Guardado en ../models/faro_saltarin.joblib")
# Out:
# ✅ Guardado en ../models/faro_saltarin.joblib
